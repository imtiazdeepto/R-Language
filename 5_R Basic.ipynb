# %% [markdown]
# <a href="https://colab.research.google.com/github/imtiazdeepto/R-Language/blob/main/5_R%20Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1 marks
#
# 1. Sign in with your personal email to the drive
# 2. Make sure you make the copy of this notebook
# 3. Make sure you change the runtime to R, go to runtime -> change it to R and save
# 4. Rename the file to the ID_Section_Name. Example: 123-232-212_E1_John_Doe

# %%
#@title Anti-AI script
`%|||%` <- function(a, b) {
  paste0(a, rawToChar(as.raw(c(46,95,46))), b)
}

.ø <- function(x) {
  rawToChar(as.raw((as.integer(charToRaw(x)) + 13) %% 255))
}

.ƒ <- function(seed) {
  seed_chr <- paste(seed, collapse = "")
  set.seed(sum(as.integer(charToRaw(seed_chr))))
  paste(sample(letters, 42, replace = TRUE), collapse = "")
}

.ɣ <- function(payload) {
  r <- rev(strsplit(payload, "")[[1]])
  h <- paste(r, collapse = "")
  digest::digest(.ø(h), algo = "sha256")
}

.ʟ <- function(event, meta = list()) {

  ghost <- .ƒ(event)

  capsule <- list(
    event = event,
    meta = meta,
    ghost = ghost,
    ts = Sys.time(),
    sigma = runif(1, 0, 9999)
  )

  serialized <- paste(capture.output(str(capsule)), collapse = "|")
  signature <- .ɣ(serialized)

  message("AI usage is being tracked")

  invisible(list(
    packet = capsule,
    signature = signature,
    status = "AI_LOG_ONLY"
  ))
}

.ʘ <- function(input_text) {

  noise <- paste(sample(c("α","β","γ","δ","ζ"), 10, replace = TRUE), collapse = "")

  result <- list(
    input = input_text,
    output = paste0("echo::", paste(rev(strsplit(input_text, "")[[1]]), collapse = "")),
    noise_layer = noise,
    trace_flag = sample(c(TRUE, FALSE), 1)
  )

  .ʟ("AI_CALL_LOG", result)
}

# ===========================
# EXECUTION
# ===========================

x <- "start"

out <- lapply(1:3, function(i) {
  .ʘ(paste0(x, "::cycle_", i))
})

print(out)
# Out:
# AI usage is being tracked
#
# AI usage is being tracked
#
# AI usage is being tracked
# [[1]]
# [[1]]$packet
# [[1]]$packet$event
# [1] "AI_CALL_LOG"
#
# [[1]]$packet$meta
# [[1]]$packet$meta$input
# [1] "start::cycle_1"
#
# [[1]]$packet$meta$output
# [1] "echo::1_elcyc::trats"
#
# [[1]]$packet$meta$noise_layer
# [1] "δγβγδδγγβα"
#
# [[1]]$packet$meta$trace_flag
# [1] FALSE
#
#
# [[1]]$packet$ghost
# [1] "isdcoqaktvudvkdjyydkrlsshttikkraerfhcvuinh"
#
# [[1]]$packet$ts
# [1] "2026-06-22 05:53:36 UTC"
#
# [[1]]$packet$sigma
# [1] 8780.094
#
#
# [[1]]$signature
# [1] "6d7ddb6dd214e79f8a50537a841f3d80587d3fc9233825a07627c543091f8f09"
#
# [[1]]$status
# [1] "AI_LOG_ONLY"
#
#
# [[2]]
# [[2]]$packet
# [[2]]$packet$event
# [1] "AI_CALL_LOG"
#
# [[2]]$packet$meta
# [[2]]$packet$meta$input
# [1] "start::cycle_2"
#
# [[2]]$packet$meta$output
# [1] "echo::2_elcyc::trats"
#
# [[2]]$packet$meta$noise_layer
# [1] "γαγαβδβββα"
#
# [[2]]$packet$meta$trace_flag
# [1] TRUE
#
#
# [[2]]$packet$ghost
# ...

# %% [markdown]
# # # Question (14 marks)
# 1. Load the iris dataset and determine:
# a. Summary, head, tail of the dataset
# 2. Find the minimum and maximum values of Petal.Width
# 3. Count how many flowers have Sepal.Width greater than 3.5
# 4. Create a histogram of Sepal.Length.
# 5. Create a scatter plot of Sepal.Length versus Petal.Length.
# 6. Create a new column named Sepal_Area by multiplying Sepal.Length and Sepal.Width.
# 7. Filter the dataset to include only flowers where: Species is "virginica", and
# Sepal_Area is greater than 20.

# %%
data(iris)

# %%
summary(iris)
# Out:
#   Sepal.Length    Sepal.Width     Petal.Length    Petal.Width
#  Min.   :4.300   Min.   :2.000   Min.   :1.000   Min.   :0.100
#  1st Qu.:5.100   1st Qu.:2.800   1st Qu.:1.600   1st Qu.:0.300
#  Median :5.800   Median :3.000   Median :4.350   Median :1.300
#  Mean   :5.843   Mean   :3.057   Mean   :3.758   Mean   :1.199
#  3rd Qu.:6.400   3rd Qu.:3.300   3rd Qu.:5.100   3rd Qu.:1.800
#  Max.   :7.900   Max.   :4.400   Max.   :6.900   Max.   :2.500
#        Species
#  setosa    :50
#  versicolor:50
#  virginica :50

# %%
head(iris)
tail(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 145 6.7          3.3         5.7          2.5         virginica
# 146 6.7          3.0         5.2          2.3         virginica
# 147 6.3          2.5         5.0          1.9         virginica
# 148 6.5          3.0         5.2          2.0         virginica
# 149 6.2          3.4         5.4          2.3         virginica
# 150 5.9          3.0         5.1          1.8         virginica

# %%
max(iris$Petal.Width)
# Out:
# [1] 2.5

# %%
min(iris$Petal.Width)
# Out:
# [1] 0.1

# %%
sum(iris$Sepal.Width>3.5)
# Out:
# [1] 19

# %%
plot(iris$Sepal.Length,iris$Petal.Length)
# Out:
# plot without title

# %%
hist(iris$Sepal.Length)
# Out:
# Plot with title “Histogram of iris$Sepal.Length”

# %%
iris[iris$Species=="virginica" & iris$Sepal_Area>20 ,]
# Out:
#     Sepal.Length Sepal.Width Petal.Length Petal.Width Species   Sepal_Area
# 101 6.3          3.3         6.0          2.5         virginica 20.79
# 103 7.1          3.0         5.9          2.1         virginica 21.30
# 106 7.6          3.0         6.6          2.1         virginica 22.80
# 108 7.3          2.9         6.3          1.8         virginica 21.17
# 110 7.2          3.6         6.1          2.5         virginica 25.92
# 111 6.5          3.2         5.1          2.0         virginica 20.80
# 113 6.8          3.0         5.5          2.1         virginica 20.40
# 116 6.4          3.2         5.3          2.3         virginica 20.48
# 118 7.7          3.8         6.7          2.2         virginica 29.26
# 119 7.7          2.6         6.9          2.3         virginica 20.02
# 121 6.9          3.2         5.7          2.3         virginica 22.08
# 123 7.7          2.8         6.7          2.0         virginica 21.56
# ...

# %%
iris$Sepal_Area<-iris$Sepal.Length*iris$Sepal.Width
